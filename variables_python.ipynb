# %% [markdown]
# # variables in python
# 1. variable is a memory allocationto a value
# 2. 2.example are `name="varshini" ` `age=16`

# %%
name="varshini"
age=16
salary=10000.65
print(name)
print(age)
print(salary)
# Out:
# varshini
# 16
# 10000.65

# %% [markdown]
# # key points to define a variables
# 1. variable does not start with digit
# 2. variables does not allowed special characters
# 3. do not use key words as a variables

# %%
1name="varshini"
print(1name)
# Out:
#   Cell In[2], line 1
#     1name="varshini"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# firstname="varshini"
# print(first@name)

# %%
first_name="varshith"
print(first_name)
# Out:
# varshith

# %%
for = "varshini"
print(for)
# Out:
#   Cell In[4], line 1
#     for = "varshini"
#         ^
# SyntaxError: invalid syntax

# %%
for1="varshini"
print(for1)
# Out:
# varshini
